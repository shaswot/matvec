# %%
# generate hardware error profile
import numpy as np
import random
import os

# %%
seed = 20210907
print("Seed: ", seed)
np.random.seed(seed)
random.seed(seed)
os.environ['PYTHONHASHSEED']=str(seed)
# Out:
# Seed:  20210907

# %%
NO_OF_THREADS = 64
NO_OF_SM = 68

# %%
error_profile = np.random.uniform(low=0.0, high=0.7, size = (NO_OF_SM, NO_OF_THREADS))
error_tag = "./data/uniform_"
np.save(error_tag + str(seed), error_profile)

# %%
error_profile
# Out:
# array([[0.37032986, 0.04928234, 0.27995963, ..., 0.6823576 , 0.23187608,
#         0.03416998],
#        [0.57768333, 0.49245121, 0.04027426, ..., 0.37175166, 0.2448559 ,
#         0.45115175],
#        [0.23379413, 0.32590608, 0.20865709, ..., 0.09522325, 0.39995942,
#         0.33003747],
#        ...,
#        [0.27257716, 0.10249305, 0.60356299, ..., 0.45279587, 0.3292645 ,
#         0.32839261],
#        [0.12902854, 0.57859202, 0.17508482, ..., 0.13574192, 0.38500929,
#         0.06345479],
#        [0.45756056, 0.2741838 , 0.57793643, ..., 0.50461979, 0.4174614 ,
#         0.12821662]])

# %%
import matplotlib.pyplot as plt
plt.imshow(error_profile, 
           cmap='hot', 
           interpolation='nearest')
plt.colorbar()
plt.show()

# %%
plt.figure(figsize = (15,5))
plt.imshow(error_profile[0:2,:], 
           cmap='hot', 
           interpolation='nearest')
plt.tight_layout()
plt.show()
